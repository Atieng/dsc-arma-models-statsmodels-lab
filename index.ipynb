# %% [markdown]
# # ARMA Models in StatsModels - Lab
#
# ## Introduction
#
# In this lesson, you'll fit an ARMA model using `statsmodels` to a real-world dataset.
#
#
# ## Objectives
#
# In this lab you will:
#
# - Decide the optimal parameters for an ARMA model by plotting ACF and PACF and interpreting them
# - Fit an ARMA model using StatsModels
#
# ## Dataset
#
# Run the cell below to import the dataset containing the historical running times for the men's 400m in the Olympic games.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning

warnings.simplefilter("ignore", ConvergenceWarning)

data = pd.read_csv("winning_400m.csv")
data["year"] = pd.to_datetime(data["year"].astype(str))
data.set_index("year", inplace=True)
data.index = data.index.to_period("Y")

# %%
# Preview the dataset
data
# Out:
#       winning_times
# year
# 1900           49.4
# 1904           49.2
# 1908           50.0
# 1912           48.2
# 1920           49.6
# 1924           47.6
# 1928           47.8
# 1932           46.2
# 1936           46.5
# 1948           46.2
# 1952           45.9
# 1956           46.7
# 1960           44.9
# 1964           45.1
# 1968           43.8
# 1972           44.7
# 1976           44.3
# 1980           44.6
# 1984           44.3
# 1988           43.9
# 1992           43.5
# 1996           43.5

# %% [markdown]
# Plot this time series data.

# %%
# Plot the time series
data.plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# If you plotted the time series correctly, you should notice that it is not stationary. So, difference the data to get a stationary time series. Make sure to remove the missing values.

# %%
data_diff = data.diff(periods=1)
data_diff.head(10)

# %%
# Difference the time series
data_diff = data.diff(periods = 1)
data_diff.dropna(inplace = True)

# %% [markdown]
# Use `statsmodels` to plot the ACF and PACF of this differenced time series.

# %%
# Plot the ACF
data_diff.plot()
# Out:
# <Axes: xlabel='year'>

# %%
# Plot the ACF
from statsmodels.graphics.tsaplots import plot_acf

fig, ax = plt.subplots(figsize=(8, 3))
plot_acf(data_diff, ax=ax, lags=8);

# %%
# Plot the PACF
# Plot the PACF
from statsmodels.graphics.tsaplots import plot_pacf

fig, ax = plt.subplots(figsize=(8, 3))
plot_pacf(data_diff, ax=ax, lags=8, method="ywm");

# %% [markdown]
# Based on the ACF and PACF, fit an ARMA model with the right orders for AR and MA. Feel free to try different models and compare AIC and BIC values, as well as significance values for the parameter estimates.

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import arma_order_select_ic

# Assuming you have a time series named 'data' with datetime index
# Replace 'data' with your actual time series data

# Plot ACF and PACF
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))

plot_acf(data_diff, lags=8, ax=ax1)
plot_pacf(data_diff, lags=8, ax=ax2)

plt.tight_layout()
plt.show()

# %%
# Example AR and MA orders (replace with your identified values)
p = 1  # AR order
q = 1  # MA order

# Fit ARMA model
arma_model = ARIMA(data_diff, order=(1, 0, 0))  # (p, d, q) with d=0 for ARMA
arma_result = arma_model.fit()

# Print summary
print(arma_result.summary())

# Alternatively, you can print AIC and BIC
print("AIC:", arma_result.aic)
print("BIC:", arma_result.bic)
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:          winning_times   No. Observations:                   21
# Model:                 ARIMA(1, 0, 0)   Log Likelihood                 -20.054
# Date:                Tue, 02 Jul 2024   AIC                             46.107
# Time:                        00:47:08   BIC                             49.241
# Sample:                    12-31-1904   HQIC                            46.787
#                          - 12-31-1996
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2885      0.081     -3.559      0.000      -0.447      -0.130
# ar.L1         -0.7186      0.144     -5.005      0.000      -1.000      -0.437
# sigma2         0.3819      0.180      2.121      0.034       0.029       0.735
# ...

# %%
# Fit ARMA model
arma_model = ARIMA(data_diff, order=(2, 0, 1))  # (p, d, q) with d=0 for ARMA
arma_result = arma_model.fit()

# Print summary
print(arma_result.summary())

# Alternatively, you can print AIC and BIC
print("AIC:", arma_result.aic)
print("BIC:", arma_result.bic)
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:          winning_times   No. Observations:                   21
# Model:                 ARIMA(2, 0, 1)   Log Likelihood                 -19.931
# Date:                Tue, 02 Jul 2024   AIC                             49.862
# Time:                        00:47:20   BIC                             55.084
# Sample:                    12-31-1904   HQIC                            50.995
#                          - 12-31-1996
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2834      0.092     -3.079      0.002      -0.464      -0.103
# ar.L1         -0.6102      2.583     -0.236      0.813      -5.673       4.453
# ar.L2          0.1280      1.848      0.069      0.945      -3.493       3.749
# ...

# %%
# Fit ARMA model
arma_model = ARIMA(data_diff, order=(2, 0, 2))  # (p, d, q) with d=0 for ARMA
arma_result = arma_model.fit()

# Print summary
print(arma_result.summary())

# Alternatively, you can print AIC and BIC
print("AIC:", arma_result.aic)
print("BIC:", arma_result.bic)
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:          winning_times   No. Observations:                   21
# Model:                 ARIMA(2, 0, 2)   Log Likelihood                 -16.472
# Date:                Tue, 02 Jul 2024   AIC                             44.943
# Time:                        00:51:59   BIC                             51.210
# Sample:                    12-31-1904   HQIC                            46.303
#                          - 12-31-1996
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2718      0.103     -2.630      0.009      -0.474      -0.069
# ar.L1         -1.7573      0.117    -14.997      0.000      -1.987      -1.528
# ar.L2         -0.9180      0.120     -7.667      0.000      -1.153      -0.683
# ...

# %%
# Plot residuals
residuals = arma_result.resid

plt.figure(figsize=(12, 6))
plt.plot(residuals)
plt.title('Residuals')
plt.show()

# Plot ACF of residuals
plot_acf(residuals, lags=40)
plt.show()

# Histogram and Q-Q plot for normality
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histogram
axes[0].hist(residuals, bins=30, density=True, alpha=0.6, color='b')
axes[0].set_title('Residual Histogram')

# Q-Q plot
import scipy.stats as stats
stats.probplot(residuals, dist="norm", plot=axes[1])
axes[1].set_title('Q-Q Plot')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 5
#       2 residuals = arma_result.resid
#       4 plt.figure(figsize=(12, 6))
# ----> 5 plt.plot(residuals)
#       6 plt.title('Residuals')
#       7 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1723, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %% [markdown]
# ## What is your final model? Why did you pick this model?

# %%
# Your comments here

# %% [markdown]
# ## Summary
#
# Well done. In addition to manipulating and visualizing time series data, you now know how to create a stationary time series and fit ARMA models.
